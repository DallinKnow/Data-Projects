# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
daily1 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailyActivity_merged.csv')
daily2 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailyCalories_merged.csv')
daily3 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailyIntensities_merged.csv')
daily4 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailySteps_merged.csv')
heartrate_seconds_merged = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/heartrate_seconds_merged.csv')

# %%
file_groups = {
    "daily": ["dailyActivity_merged.csv", "dailyCalories_merged.csv", "dailyIntensities_merged.csv", "dailySteps_merged.csv"],
    "hourly": ["hourlyCalories_merged.csv", "hourlyIntensities_merged.csv", "hourlySteps_merged.csv"],
    "minute": ["minuteCaloriesNarrow_merged.csv", "minuteCaloriesWide_merged.csv", "minuteIntensitiesNarrow_merged.csv", "minuteIntesnsitiesWide_merged.csv", "minuteMETsNarrow_merged.csv", "minuteSleep_merged.csv", "minuteStepsNarrow_merged.csv", "minutesStepsWide_merged.csv"],
    "info": ["heartrate_seconds_merged.csv", "sleepDay_merged.csv", "weightLogInfo_merged.csv"]
}

data = {}
for group, files in file_groups.item():
    data[group] = {
    f.replace(".csv", " "): pd.read_csv(os.path.join('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16', f))
    for f in files
    }
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 9
#       5     "info": ["heartrate_seconds_merged.csv", "sleepDay_merged.csv", "weightLogInfo_merged.csv"]
#       6 }
#       7
#       8 data = {}
# ----> 9 for group, files in file_groups.item():
#      10     data[group] = {
#      11     f.replace(".csv", " "): pd.read_csv(os.path.join('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16', f))
#      12     for f in files
#
# AttributeError: 'dict' object has no attribute 'item'

# %%
for i in range(0,5):
    print(str("Data Frame " + i +" : ") + str("daily" + i + ".head()"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in range(0,5):
# ----> 2     print(str("Data Frame " + i +" : ") + str("daily" + i + ".head()"))
#
# TypeError: can only concatenate str (not "int") to str
