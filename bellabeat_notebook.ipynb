# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
daily1 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailyActivity_merged.csv')
daily2 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailyCalories_merged.csv')
daily3 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailyIntensities_merged.csv')
daily4 = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/dailySteps_merged.csv')
heartrate_seconds_merged = pd.read_csv('data/fitbit_exp_4/Fitabase data 4.12.16-5.12.16/heartrate_seconds_merged.csv')

# %%
file_group = {
    "daily": ["daily_activity.csv", "daily_calories.csv", "daily_intensities.csv", "daily_steps.csv"],
    "hourly": ["hourly_calories.csv", "hourly_intensities.csv", "hourly_steps.csv"],
    "minute": ["minute_calories_narrow", "minute_calories_wide", "minute_intensities_narrow", "minute_intesnsities_wide", "minute_mets_narrow", "minute_sleep", "minute_steps_narrow"],
    "info": ["heartrate_seconds.csv", "sleep_day.csv", "weightLogInfo.csv"]
}

data = {}
for group, files in file_group.item():
    data[group]  {
    f.replace(".csv", " "): pd.read_csv(os.path.join("data", f))
    for f in files
    }
# Out:
#   Cell In[7], line 4
#     "minute": ["minute_calories_narrow", "minute_calories_wide", "minute_intensities_narrow", "minute_intesnsities_wide"]
#                                                                                                                          ^
# _IncompleteInputError: incomplete input

# %%
for i in range(0,5):
    print(str("Data Frame " + i +" : ") + str("daily" + i + ".head()"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in range(0,5):
# ----> 2     print(str("Data Frame " + i +" : ") + str("daily" + i + ".head()"))
#
# TypeError: can only concatenate str (not "int") to str
