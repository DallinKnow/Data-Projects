# %% [markdown]
# # 🐍 Cyclistic Python Data Project

# %% [markdown]
# ### ❓ Business Question:  " How do casual riders and members use Cyclistic bikes differently? "

# %% [markdown]
# ##### ( Cyclistic is a company that rents bikes to customers and is wanting to increase their revenue by turning casual riders into paying members. )

# %% [markdown]
# ## 🧹 Data Cleaning

# %% [markdown]
# ### ⏬📩 Importing data and tools

# %%
# Importing tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
# Loading 2025 monthly data into separate DataFrames to be merged later
df_1 = pd.read_csv('202501-divvy-tripdata.csv')
df_2 = pd.read_csv('202502-divvy-tripdata.csv')
df_3 = pd.read_csv('202503-divvy-tripdata.csv')
df_4 = pd.read_csv('202504-divvy-tripdata.csv')
df_5 = pd.read_csv('202505-divvy-tripdata.csv')
df_6 = pd.read_csv('202506-divvy-tripdata.csv')
df_7 = pd.read_csv('202507-divvy-tripdata.csv')
df_8 = pd.read_csv('202508-divvy-tripdata.csv')
df_9 = pd.read_csv('202509-divvy-tripdata.csv')
df_10 = pd.read_csv('202510-divvy-tripdata.csv')
df_11 = pd.read_csv('202511-divvy-tripdata.csv')
df_12 = pd.read_csv('202512-divvy-tripdata.csv')
# Loading 2024 monthly data into separate DataFrames to be merged later
df_13 = pd.read_csv('202401-divvy-tripdata.csv')
df_14 = pd.read_csv('202402-divvy-tripdata.csv')
df_15 = pd.read_csv('202403-divvy-tripdata.csv')
df_16 = pd.read_csv('202404-divvy-tripdata.csv')
df_17 = pd.read_csv('202405-divvy-tripdata.csv')
df_18 = pd.read_csv('202406-divvy-tripdata.csv')
df_19 = pd.read_csv('202407-divvy-tripdata.csv')
df_20 = pd.read_csv('202408-divvy-tripdata.csv')
df_21 = pd.read_csv('202409-divvy-tripdata.csv')
df_22 = pd.read_csv('202410-divvy-tripdata.csv')
df_23 = pd.read_csv('202411-divvy-tripdata.csv')
df_24 = pd.read_csv('202412-divvy-tripdata.csv')

# %%
# Checking the dataframes for consistency before merging
df_1.info()
df_2.info()
df_3.info()
df_4.info()
df_5.info()
df_6.info()
df_7.info()
df_8.info()
df_9.info()
df_10.info()
df_11.info()
df_12.info()
df_13.info()
df_14.info()
df_15.info()
df_16.info()
df_17.info()
df_18.info()
df_19.info()
df_20.info()
df_21.info()
df_22.info()
df_23.info()
df_24.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 138689 entries, 0 to 138688
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             138689 non-null  str
#  1   rideable_type       138689 non-null  str
#  2   started_at          138689 non-null  str
#  3   ended_at            138689 non-null  str
#  4   start_station_name  115837 non-null  str
#  5   start_station_id    115837 non-null  str
#  6   end_station_name    114616 non-null  str
#  7   end_station_id      114616 non-null  str
#  8   start_lat           138689 non-null  float64
#  9   start_lng           138689 non-null  float64
#  10  end_lat             138628 non-null  float64
#  11  end_lng             138628 non-null  float64
#  12  member_casual       138689 non-null  str
# dtypes: float64(4), str(9)
# memory usage: 13.8 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 151880 entries, 0 to 151879
# ...

# %%
# Combine all monthly DataFrames into one for the entire 2024-2025 period
df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22, df_23, df_24], ignore_index=True)

# %%
# Checking the combined DataFrame after merging
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  7569BC890583FCD7   classic_bike  2025-01-21 17:23:54.538
# 1  013609308856B7FC  electric_bike  2025-01-11 15:44:06.795
# 2  EACACD3CE0607C0D   classic_bike  2025-01-02 15:16:27.730
# 3  EAA2485BA64710D3   classic_bike  2025-01-23 08:49:05.814
# 4  7F8BE2471C7F746B  electric_bike  2025-01-16 08:38:32.338
#
#                   ended_at            start_station_name start_station_id  \
# 0  2025-01-21 17:37:52.015     Wacker Dr & Washington St     KA1503000072
# 1  2025-01-11 15:49:11.139   Halsted St & Wrightwood Ave     TA1309000061
# 2  2025-01-02 15:28:03.230  Southport Ave & Waveland Ave            13235
# 3  2025-01-23 08:52:40.047  Southport Ave & Waveland Ave            13235
# 4  2025-01-16 08:41:06.767  Southport Ave & Waveland Ave            13235
#
#             end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0       McClurg Ct & Ohio St   TA1306000029  41.883143 -87.637242  41.892592
# ...

# %% [markdown]
# ### ❌🗑 Checking and deleting null values

# %%
# Checking for null values in the combined DataFrame
df.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name    2258624
# start_station_id      2258624
# end_station_name      2347958
# end_station_id        2347958
# start_lat                   0
# start_lng                   0
# end_lat                 12767
# end_lng                 12767
# member_casual               0
# dtype: int64

# %%
# Found null values, but lattitude and longitude end values are not equal to start station and end station values
# Dropping null values in end_latitude and end_longitude columns
df.dropna(subset=['end_lat', 'end_lng'], inplace=True)

# %%
# Checking for null values in the combined DataFrame after dropping
df.isnull().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name    2258624
# start_station_id      2258624
# end_station_name      2335191
# end_station_id        2335191
# start_lat                   0
# start_lng                   0
# end_lat                     0
# end_lng                     0
# member_casual               0
# dtype: int64

# %%
# End station nulls not equal to start station for some entries - dropping all null values for simplicity
df.dropna(inplace=True)

# %%
# Checking for null values in the combined DataFrame after dropping
df.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
# All null values have been addressed
# Checking for duplicate entries in the combined DataFrame
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# No duplicate entries found
# Checking the values after cleaning
df['member_casual'].value_counts()
# Out:
# member_casual
# member    5056677
# casual    2844886
# Name: count, dtype: int64

# %%
# Checking the values after cleaning
df['rideable_type'].value_counts()
# Out:
# rideable_type
# classic_bike        4670555
# electric_bike       3183181
# electric_scooter      47827
# Name: count, dtype: int64

# %% [markdown]
# ### ⌚🚲 Creating 'ride_duration' column to better find relation between casual riders and members and their bike usage

# %%
# Checking values for consistency in start and end time columns to measure ride duration
df['started_at'].head()
df['ended_at'].head()
# Out:
# 0    2025-01-21 17:37:52.015
# 1    2025-01-11 15:49:11.139
# 2    2025-01-02 15:28:03.230
# 3    2025-01-23 08:52:40.047
# 4    2025-01-16 08:41:06.767
# Name: ended_at, dtype: str

# %%
# Check for inconsistant date time stamps, finding the number of invalid date time stamps in start and end time columns
started_temp = pd.to_datetime(df['started_at'], errors='coerce')
invalid_started = started_temp.isna().sum()
print(f"Invalid 'started_at' count: {invalid_started}")
# Out:
# Invalid 'started_at' count: 1268788

# %%
# Check for inconsistant date time stamps, finding the number of invalid date time stamps in start and end time columns
ended_temp = pd.to_datetime(df['ended_at'], errors='coerce')
invalid_ended = ended_temp.isna().sum()
print(f"Invalid 'ended_at' count: {invalid_ended}")
# Out:
# Invalid 'ended_at' count: 1268788

# %%
# The count on both start and end time columns are the same, so we can reformat the invalid date time stamps to NaT
# and recalculate the ride duration
df['ride_duration'] = pd.to_datetime(df['ended_at'], errors='coerce') - pd.to_datetime(df['started_at'], errors='coerce')

# %%
# Checking for null values in the combined DataFrame after reformatting date time stamps
df.isna().sum()
# Out:
# ride_id                     0
# rideable_type               0
# started_at                  0
# ended_at                    0
# start_station_name          0
# start_station_id            0
# end_station_name            0
# end_station_id              0
# start_lat                   0
# start_lng                   0
# end_lat                     0
# end_lng                     0
# member_casual               0
# ride_duration         1268788
# dtype: int64

# %%
# Dropping null values from ride duration
df.dropna(inplace=True)

# %%
# Checking data after dropping null values from ride duration
df.isna().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# ride_duration         0
# dtype: int64

# %%
# Looking for out of the ordinary values in ride duration
df['ride_duration'].describe()
# Out:
# count                     6632775
# mean       0 days 00:16:23.914344
# std        0 days 00:34:33.079326
# min      -1 days +23:04:34.458000
# 25%        0 days 00:05:51.148000
# 50%        0 days 00:10:06.937000
# 75%        0 days 00:18:01.566000
# max        1 days 00:59:38.262000
# Name: ride_duration, dtype: object

# %% [markdown]
# ### 🔎 Finding any outliers or false starts/trips to keep data acurate and to the point

# %%
# finding how many rides have a duration of 10 seconds or less for false entries in the data or nonriders
zero_or_negative_duration = (df['ride_duration'] <= pd.Timedelta(seconds=10)).sum()
print(f"Number of rides with duration of 10 seconds or less: {zero_or_negative_duration}")
# Out:
# Number of rides with duration of 10 seconds or less: 12111

# %%
# finding how many rides have a duration of 24 hours or more for simplicity in the data and to drop outliers that will skew the data
long_duration = (df['ride_duration'] >= pd.Timedelta(24, unit='hours')).sum()
print(f"Number of rides with duration of 24 hours or more: {long_duration}")
# Out:
# Number of rides with duration of 24 hours or more: 201

# %%
# Dropping rides with duration of 10 seconds or less or more than 24 hours
df = df[(df['ride_duration'] > pd.Timedelta(seconds=10)) & (df['ride_duration'] < pd.Timedelta(24, unit='hours'))]

# %%
# Looking for out of the ordinary values in ride duration after dropping outliers
df['ride_duration'].describe()
# Out:
# count                   6620463
# mean     0 days 00:16:23.074992
# std      0 days 00:33:38.188420
# min      0 days 00:00:10.001000
# 25%      0 days 00:05:52.374000
# 50%      0 days 00:10:08.042000
# 75%      0 days 00:18:02.887500
# max      0 days 23:59:58.557000
# Name: ride_duration, dtype: object

# %%
# Checking for null or bad syntax in started_at column
started_temp = pd.to_datetime(df['started_at'], errors='coerce')
invalid_started = started_temp.isna().sum()
print(f"Invalid 'started_at' count: {invalid_started}")
# Out:
# Invalid 'started_at' count: 0

# %%
# Checking for null
df.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# ride_duration         0
# dtype: int64

# %% [markdown]
# ### 👷‍♀️🚧👷‍♂️ Creating 3 last columns to find the regular days, times, and months of bike use between members and casual riders

# %%
# With data cleaned, I will now prepare three last columns for analysis: day of the week, month, and hour of the day. 
# I will extract this information from the start time column.
df['started_at'] = pd.to_datetime(df['started_at'])
df['start_day'] = df['started_at'].dt.day_name()
df['start_month'] = df['started_at'].dt.month_name()
df['start_hour'] = df['started_at'].dt.hour
df['start_year'] = df['started_at'].dt.year

# %%
df["ride_duration_min"] = round(df['ride_duration'].dt.total_seconds()/60, 2)

# %%
# Final check of data after cleaning
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6620463 entries, 0 to 11413560
# Data columns (total 19 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             str
#  1   rideable_type       str
#  2   started_at          datetime64[us]
#  3   ended_at            str
#  4   start_station_name  str
#  5   start_station_id    str
#  6   end_station_name    str
#  7   end_station_id      str
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       str
#  13  ride_duration       timedelta64[us]
#  14  start_day           str
#  15  start_month         str
#  16  start_hour          int32
#  17  start_year          int32
#  18  ride_duration_min   float64
# dtypes: datetime64[us](1), float64(5), int32(2), str(10), timedelta64[us](1)
# memory usage: 959.7 MB

# %%
df.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  7569BC890583FCD7   classic_bike 2025-01-21 17:23:54.538
# 1  013609308856B7FC  electric_bike 2025-01-11 15:44:06.795
# 2  EACACD3CE0607C0D   classic_bike 2025-01-02 15:16:27.730
# 3  EAA2485BA64710D3   classic_bike 2025-01-23 08:49:05.814
# 4  7F8BE2471C7F746B  electric_bike 2025-01-16 08:38:32.338
#
#                   ended_at            start_station_name start_station_id  \
# 0  2025-01-21 17:37:52.015     Wacker Dr & Washington St     KA1503000072
# 1  2025-01-11 15:49:11.139   Halsted St & Wrightwood Ave     TA1309000061
# 2  2025-01-02 15:28:03.230  Southport Ave & Waveland Ave            13235
# 3  2025-01-23 08:52:40.047  Southport Ave & Waveland Ave            13235
# 4  2025-01-16 08:41:06.767  Southport Ave & Waveland Ave            13235
#
#             end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0       McClurg Ct & Ohio St   TA1306000029  41.883143 -87.637242  41.892592
# ...

# %% [markdown]
# # 📊 Data Analysis

# %%
df.describe()
# Out:
#                        started_at     start_lat     start_lng       end_lat  \
# count                     6620463  6.620463e+06  6.620463e+06  6.620463e+06
# mean   2025-02-24 20:13:09.478688  4.190032e+01 -8.764439e+01  4.190088e+01
# min    2024-05-31 11:49:34.737000  4.164850e+01 -8.785797e+01  4.164850e+01
# 25%    2024-09-05 08:12:55.239500  4.188096e+01 -8.765694e+01  4.188103e+01
# 50%    2025-03-26 12:56:34.721000  4.189472e+01 -8.764098e+01  4.189563e+01
# 75%    2025-08-05 00:18:42.876000  4.192562e+01 -8.762769e+01  4.192628e+01
# max    2025-12-31 23:53:24.274000  4.206487e+01 -8.752748e+01  4.206485e+01
# std                           NaN  4.279335e-02  2.615216e-02  4.298764e-02
#
#             end_lng           ride_duration    start_hour    start_year  \
# count  6.620463e+06                 6620463  6.620463e+06  6.620463e+06
# mean  -8.764471e+01  0 days 00:16:23.074992  1.395932e+01  2.024557e+03
# ...

# %%
hourly = df.groupby(['start_hour', 'member_casual'])['ride_duration_min'].mean().reset_index()

sns.lineplot(data=hourly, x='start_hour', y='ride_duration_min', hue='member_casual', linewidth=2.5, marker='o', palette={'member': '#0D6EFD', 'casual': '#E8441A'})
plt.title('Average Ride Duration by Hour of Day', fontsize=14, fontweight='bold')
plt.xlabel('Hour of Day (0 = midnight)')
plt.ylabel('Avg Duration (minutes)')
plt.xticks(range(0,24))
plt.legend(title= 'Rider Type')
plt.tight_layout()
plt.show()

# %%
hourly_count = df.groupby(['start_hour', 'member_casual']).size().reset_index(name='ride_count')

sns.lineplot(data=hourly_count, x='start_hour', y='ride_count', hue='member_casual', linewidth=2.5, marker='o', palette={'member': '#0D6EFD', 'casual': '#E8441A'})
plt.title('Number of Rides by Hour of Day', fontsize=14, fontweight='bold')
plt.xlabel('Hour of Day (0 = midnight)')
plt.ylabel('Number of Rides')
plt.xticks(range(0,24))
plt.legend(title= 'Rider Type')
plt.tight_layout()
plt.show()

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
daily_average = df.groupby(['start_day', 'member_casual'])['ride_duration_min'].mean().reset_index()
sns.barplot(data=daily_average, x='start_day', y='ride_duration_min', hue='member_casual', order=day_order, palette={'member': '#0D6EFD', 'casual': '#E8441A'},
    errorbar=None)
plt.title('Average Ride Duration by Day of Week', fontsize=14, fontweight='bold')
plt.xlabel('Day of Week')
plt.ylabel('Avg Duration (minutes)')
plt.xticks(rotation=30)
plt.legend(title='Rider Type')
plt.tight_layout()
plt.show()

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
daily_count = df.groupby(['start_day', 'member_casual']).size().reset_index(name='ride_count')
sns.barplot(data=daily_count, x='start_day', y='ride_count', hue='member_casual', order=day_order, palette={'member': "#0D6EFD", 'casual': "#E8441A"},
    errorbar=None)
plt.title('Ride Count by Day of Week', fontsize=14, fontweight='bold')
plt.xlabel('Day of Week')
plt.ylabel('Ride Count')
plt.xticks(rotation=30)
plt.legend(title='Rider Type')
plt.tight_layout()
plt.show()

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
month_average = df.groupby(['start_month', 'member_casual'])['ride_duration_min'].mean().reset_index()
sns.barplot(data=month_average, x='start_month', y='ride_duration_min', hue='member_casual', order=month_order, palette={'member': '#0D6EFD', 'casual': '#E8441A'},
    errorbar=None)
plt.title('Average Ride Duration by Month', fontsize=14, fontweight='bold')
plt.xlabel('Month')
plt.ylabel('Average Ride Duration (minutes)')
plt.xticks(rotation=30)
plt.legend(title='Rider Type')
plt.tight_layout()
plt.show()

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
month_count = df.groupby(['start_month', 'member_casual']).size().reset_index(name='ride_count')
sns.barplot(data=month_count, x='start_month', y='ride_count', hue='member_casual', order=month_order, palette={'member': '#0D6EFD', 'casual': '#E8441A'},
    errorbar=None)
plt.title('Ride Count by Month', fontsize=14, fontweight='bold')
plt.xlabel('Month')
plt.ylabel('Ride Count')
plt.xticks(rotation=30)
plt.legend(title='Rider Type')
plt.tight_layout()
plt.show()

# %%
rideable_type_count = df[df['rideable_type'].isin(['classic_bike', 'electric_bike'])].groupby(['rideable_type', 'member_casual']).size().reset_index(name='ride_count')
sns.barplot(data=rideable_type_count, x='rideable_type', y='ride_count', hue='member_casual', palette={'member': '#0D6EFD', 'casual': '#E8441A'}, errorbar=None)
plt.title('Ride Count by Bike Type', fontsize=14, fontweight='bold')
plt.xlabel('Bike Type')
plt.ylabel('Ride Count')
plt.legend(title='Rider Type')
plt.tight_layout()
plt.show()

# %%
test_df = df[df['ride_duration_min']<60].copy()

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.boxplot(data=test_df, x='member_casual', y='ride_duration_min', palette= {'member': "#0D6EFD", 'casual': '#e8441A'}, width= 0.4, flierprops=dict(marker='o', markersize=2, alpha=0.2))
plt.title('Ride Duratoin Distribution')
plt.xlabel('Rider Type')
plt.ylabel('Ride Duration (minutes)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rebekah\AppData\Local\Temp\ipykernel_11084\249921115.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=test_df, x='member_casual', y='ride_duration_min', palette= {'member': "#0D6EFD", 'casual': '#e8441A'}, width= 0.4, flierprops=dict(marker='o', markersize=2, alpha=0.2))

# %%
rider_counts = df['member_casual'].value_counts()

fig, ax = plt.subplots(figsize= (6,6))

ax.pie(
    rider_counts,
    labels = rider_counts.index,
    colors = ['#0D6EFD', '#E8441A'],
    autopct = '%1.1f%%',
    startangle = 90,
    wedgeprops = dict(width = 0.5)
)

ax.set_title('Ryder Type', fontsize = 14, fontweight= 'bold')
plt.tight_layout()
plt.show()

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']


fig, axes = plt.subplots(2,2, figsize=(20,12))

sns.lineplot(data=hourly, x='start_hour', y='ride_duration_min', hue='member_casual', linewidth=2.5, marker='o', palette={'member': '#0D6EFD', 'casual': '#E8441A'}, ax=axes[0][0])
axes[0][0].set_title('Average Ride Duration by Hour of Day', fontsize=14, fontweight='bold')
axes[0][0].set_xlabel('Hour of Day (0 = midnight)')
axes[0][0].set_ylabel('Avg Duration (minutes)')
axes[0][0].set_xticks(range(0,24))
axes[0][0].legend(title='Rider Type')

daily_average = df.groupby(['start_day', 'member_casual'])['ride_duration_min'].mean().reset_index()
sns.barplot(data=daily_average, x='start_day', y='ride_duration_min', hue='member_casual', order=day_order, palette={'member': '#0D6EFD', 'casual': '#E8441A'},
    errorbar=None, ax=axes[0][1])
axes[0][1].set_title('Average Ride Duration by Day of Week', fontsize=14, fontweight='bold')
axes[0][1].set_xlabel('Day of Week')
axes[0][1].set_ylabel('Avg Duration (minutes)')
axes[0][1].set_xticklabels(axes[0][1].get_xticklabels(), rotation=30, ha='right')
axes[0][1].legend(title='Rider Type')

month_average = df.groupby(['start_month', 'member_casual'])['ride_duration_min'].mean().reset_index()
sns.barplot(data=month_average, x='start_month', y='ride_duration_min', hue='member_casual', order=month_order, palette={'member': '#0D6EFD', 'casual': '#E8441A'},
    errorbar=None, ax=axes[1][0])
axes[1][0].set_title('Average Ride Duration by Month', fontsize=14, fontweight='bold')
axes[1][0].set_xlabel('Month')
axes[1][0].set_ylabel('Average Ride Duration (minutes)')
axes[1][0].set_xticklabels(axes[1][0].get_xticklabels(), rotation=30, ha='right')
axes[1][0].legend(title='Rider Type')

axes[1][1].pie(
    rider_counts, labels = rider_counts.index, colors = ['#0D6EFD', '#E8441A'], autopct = '%1.1f%%',
    startangle = 90, wedgeprops = dict(width = 0.5))
axes[1][1].set_title('Rider Type', fontsize = 14, fontweight= 'bold')


plt.tight_layout()
plt.savefig('cyclistic_dashboard_1.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Rebekah\AppData\Local\Temp\ipykernel_11084\2719343416.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0][1].set_xticklabels(axes[0][1].get_xticklabels(), rotation=30, ha='right')
# C:\Users\Rebekah\AppData\Local\Temp\ipykernel_11084\2719343416.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1][0].set_xticklabels(axes[1][0].get_xticklabels(), rotation=30, ha='right')

# %%
fig, axes = plt.subplots(2,2, figsize = (20,12))

sns.lineplot(data = hourly_count, x = 'start_hour', y = 'ride_count', hue = 'member_casual', linewidth = 2.5, marker = 'o', palette = {'member' : '#0D6EFD', 'casual' : '#E8441A'}, ax=axes[0][0] )
axes[0][0].set_title('Number of Rides by Hour of Day', fontsize=14, fontweight='bold')
axes[0][0].set_xlabel('Hour of Day (0 = midnight)')
axes[0][0].set_ylabel('Number of Rides')
axes[0][0].set_xticks(range(0,24))
axes[0][0].legend(title = 'Rider Type')

sns.barplot(data=daily_count, x='start_day', y='ride_count', hue='member_casual', order=day_order, palette={'member': "#0D6EFD", 'casual': "#E8441A"},
    errorbar=None, ax=axes[0][1])
axes[0][1].set_title('Ride Count by Day of Week', fontsize=14, fontweight='bold')
axes[0][1].set_xlabel('Day of the Week')
axes[0][1].set_ylabel('Ride Count')
axes[0][1].set_xticklabels(axes[0][1].get_xticklabels(), rotation=30, ha='right')
axes[0][1].legend(title = 'Rider Type')

sns.barplot(data = month_count, x = 'start_month', y = 'ride_count', hue = 'member_casual', order = month_order, palette = {'member' : '#0D6EFD', 'casual' : '#E8441A'}, errorbar=None, ax=axes[1][0])
axes[1][0].set_title('Ride Count by Month', fontsize=14, fontweight='bold')
axes[1][0].set_xlabel('Month')
axes[1][0].set_ylabel('Ride Count')
axes[1][0].set_xticklabels(axes[1][0].get_xticklabels(), rotation=30, ha='right')
axes[1][0].legend(title = 'Rider Type')

axes[1][1].pie(rider_counts, labels = rider_counts.index, colors = ['#0D6EFD', '#E8441A'], autopct = '%1.1f%%',
    startangle = 90, wedgeprops = dict(width = 0.5))
axes[1][1].set_title('Rider Type', fontsize = 14, fontweight = 'bold')

plt.tight_layout()
plt.savefig('cyclistic_dashboard_2.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Rebekah\AppData\Local\Temp\ipykernel_11084\2201387255.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0][1].set_xticklabels(axes[0][1].get_xticklabels(), rotation=30, ha='right')
# C:\Users\Rebekah\AppData\Local\Temp\ipykernel_11084\2201387255.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1][0].set_xticklabels(axes[1][0].get_xticklabels(), rotation=30, ha='right')

# %%
season_count = month_count.copy()
season_count['start_month'] = pd.Categorical(season_count['start_month'], categories = month_order, ordered = True)
season_count = season_count.sort_values('start_month')

season_average = month_average.copy()
season_average['start_month'] = pd.Categorical(season_average['start_month'], categories = month_order, ordered = True)
season_average = season_average.sort_values('start_month')

fig, ax = plt.subplots(2,1,figsize = (12,10))

sns.lineplot(data = season_count, x = 'start_month', y = 'ride_count', hue = 'member_casual', linewidth = 2.5, marker = 'o', palette = {'member' : '#0D6EFD', 'casual' : '#E8441A'}, ax = ax[0])
ax[0].set_title('Seasonal Ride Count by Month', fontsize=14, fontweight='bold')
season_labels = {'January' : '', 'February' : 'Winter', 'March' : '', 'April' : '', 'May': 'Spring', 'June' : '', 'July' : '', 'August' : 'Summer', 'September' : '', 'October' : '', 'November' : 'Fall', 'December' : '' }
ax[0].set_xticklabels([season_labels[m] for m in month_order], fontsize = 12)
ax[0].set_ylabel('Ride Count')
ax[0].set_xlabel('Seasons')
ax[0].tick_params(axis='x', rotation=30)
ax[0].legend(title='Rider Type')

sns.lineplot(data = season_average, x = 'start_month', y = 'ride_duration_min', hue = 'member_casual', linewidth = 2.5, marker = 'o', palette = {'member' : '#0D6EFD', 'casual' : '#E8441A'}, ax = ax[1])
ax[1].set_title('Seasonal Ride Average by Month', fontsize=14, fontweight='bold')
ax[1].set_xticklabels([season_labels[m] for m in month_order], fontsize = 12)
ax[1].set_ylabel('Average Ride Duration (minutes)')
ax[1].set_xlabel('Seasons')
ax[1].tick_params(axis='x', rotation=30)
ax[1].legend(title='Rider Type')

plt.tight_layout()
plt.savefig('cyclistic_seasonal_ride_count.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Rebekah\AppData\Local\Temp\ipykernel_11084\699778945.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels([season_labels[m] for m in month_order], fontsize = 12)
# C:\Users\Rebekah\AppData\Local\Temp\ipykernel_11084\699778945.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels([season_labels[m] for m in month_order], fontsize = 12)
